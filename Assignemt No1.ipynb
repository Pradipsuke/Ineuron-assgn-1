# %% [markdown]
# # 1. In the below elements which of them are values or an expression? eg:- values can be
# #integer or string and expressions will be mathematical operators.
#
#
# #  * - expression
# #  hello- value
# #  -87.8-value
# #  /-expression
# #  +-expression
# #  6-valus """

# %% [markdown]
# # 2.What is the difference between string and variable?
#
#
# String- string we can write like "pradip",'pradip' string is nothing but a list of character in order.ex
# print("this is my first program")
#
#  variable- A variable is something that hold a value ex.
# lucky=7
#
#
# print(lucky)

# %% [markdown]
# # 3.Describe three different data types.
#
# integer- numeric value can be interger
#
# list- list are used t store multiple items in a single variable
#
# complex number- it is represented by complex class  specified as (real part)+(imaginary part)

# %% [markdown]
# # 4. What is an expression made up of? What do all expressions do?
#
#
# An Expression is a sequence or combination of values, variables, operators and function calls
#
# that always produces or returns a result value ex.
#
# b=4*7

# %% [markdown]
# # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Ans-Expression is made up of values, containers, and mathematical operators
#
# and the statement is just like a command that a python interpreter executes like print

# %% [markdown]
# # 6.After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
# Ans- It gives as outpt -23

# %% [markdown]
# # 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
#
# 'spam' * 3
#
# Ans -spamspamspam

# %% [markdown]
# # 8 Why is eggs a valid variable name while 100 is invalid?
#
# Ans- because we can't start giving variable an integer name. if we, we should begin with,
#
# a string-like alphabet name then integer. e100 or eggs100 is valid

# %% [markdown]
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#  Ans-  str(), int(), float()

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# I have eaten' + 99 + 'burritos'
#
#
# Ans- because 99 is an integer it cannot be concatenated with strings
# if we have to concatenate it we need to do typecasting.
#
# str("I have eaten' + 99 + 'burritos")
